# %% [markdown]
# <a href="https://colab.research.google.com/github/HongYeongPyo/first-repository/blob/master/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_chap_01_%EC%8B%9C%EA%B0%81%ED%99%94_250507.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1-2 파이썬으로 그래프 그린다는 건?

# %%
pwd
# Out:
# '/content'

# %%
# !pip list | grep matplotlib
# !pip list | grep seaborn
# Out:
# matplotlib                            3.10.0
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# seaborn                               0.13.2

# %% [markdown]
# 다음은 간단한 막대그래프를 그리는 전체 코드입니다.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")

# 보여주기
plt.savefig('./barplot.png')  # 그래프를 이미지로 출력
plt.show()                    # 그래프를 화면으로 출력

# %% [markdown]
# # 1-3 간단한 그래프 그리기 (1) 막대그래프

# %% [markdown]
# 우선 모듈을 import 하고 그래프로 그릴 데이터를 정의해 줍니다.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# %% [markdown]
# 도화지에 축을 그리는 과정이에요.

# %%
# 축 그리기
fig = plt.figure() #도화지(그래프) 객체 생성
ax1 = fig.add_subplot(1,1,1) #figure()객체에 add_subplot 메서드를 이용해 축을 그려준다.

# %% [markdown]
# 만약 fig = plt.figure()만 입력하면,

# %%
fig = plt.figure()

# %% [markdown]
# 축이 없어 그려지는 것이 없지만 figure 객체가 생성되었습니다.

# %% [markdown]
# 라이브러리마다 공식 API 문서
#
# https://matplotlib.org/stable/api/figure_api.html#module-matplotlib.figure

# %%
fig = plt.figure(figsize=(5,2))
ax1 = fig.add_subplot(1,1,1)

# %% [markdown]
# 그래프 몇 개를 추가해 볼게요.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax34= fig.add_subplot(2,2,4)

# %%
# Q. 아래와 같은 그래프를 만드는 코드를 작성해보세요!
fig2 = plt.figure()
# [[YOUR CODE]]

ax1 = fig2.add_subplot(2,3,1)
ax2 = fig2.add_subplot(2,3,4)
ax3 = fig2.add_subplot(2,3,5)
ax4 = fig2.add_subplot(2,3,6)

# %% [markdown]
# ## 그래프 그리기

# %% [markdown]
# - bar() 메서드를 이용해 막대그래프를 그립니다.
# - 그리고 인자에 위에서 정의한 데이터들을 x, y순으로 넣어 줍니다.

# %%
# 그래프 데이터
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### 그래프 요소 추가

# %%
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yunna's Test Result")
# Out:
# Text(0.5, 1.0, "Yunna's Test Result")

# %% [markdown]
# 이제 이전 스텝에 보았던 전체 그래프 그리기 코드가 다시 완성되었습니다.

# %%
# Q. 아래 코드의 빈칸을 채워주세요.
# 그래프 데이터
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
# [[YOUR CODE]]
fig = plt.figure()
ax1 = fig.add_subplot(1, 1,1)


# 그래프 그리기
# [[YOUR CODE]]
ax1.bar(subject, points)


# 라벨, 타이틀 달기
# [[YOUR CODE]]

plt.xlabel('subject')
plt.ylabel('points')
# Out:
# Text(0, 0.5, 'points')

# %% [markdown]
# # 1-4 간단한 그래프 그리기(2) 선그래프

# %% [markdown]
# 터미널에서 클라우드에 미리 저장된 파일에 심볼릭 링크를 걸어 데이터를 사용할 수 있도록 합니다.

# %% [markdown]
# - mkdir -p ~/aiffel/data_visualization
# - In -s ~/data ~/aiffel/data_visualization-

# %% [markdown]
# 이번엔 주석(annotation) 등 좀 더 고급 기법을 활용하여 그래프를 그려 볼까요?

# %%
pwd
# Out:
# '/content'

# %%
#Google Drive 마운트

from google.colab import drive
drive.mount('/content/drive')

#코드 실행 후 Google 계정 인증 절차를 따라야 합니다
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import pandas as pd
import os
import matplotlib.pyplot as plt

#그래프 그리기
#csv_path = os.getenv("Home") + "/aifffel/data_visualization/data/ANZN.csv"
#data = pd.read_csv(csv_path, index_col+0, parse_dates=True)

csv_path = '/content/drive/MyDrive/content/data_visual/AMZN.csv'
data = pd.read_csv(csv_path, index_col=0, parse_dates=True)
price = data['Close']

#축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

price.plot(ax=ax, style = 'black')
plt.ylim([1600, 2200])
plt.xlim(['2019-05-01', '2020-03-01'])

#주석달기
important_data = [(datetime(2019, 6, 3), "Low Price"), (datetime(2020, 2, 19), "Peak Price")]
for d, label in important_data:
    ax.annotate(
        label, xy=(d, price.asof(d) + 10),    # 주석을 달 좌표(x,y)
        xytext = (d, price.asof(d) +100),                  # 주석 텍스트가 위치할 좌표(x, y
        arrowprops=dict(facecolor = 'red'))                # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %% [markdown]
# grid() 메서드를 이용하면 그리드(격자눈금)를 추가할 수 있어요.

# %%
# Q. 날짜별 종가(Close)가 아닌 최고가(High) 데이터를 이용해서 위와 같은 그래프를 그려보세요!
# 그래프 데이터
#csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/AMZN.csv"

csv_path = '/content/drive/MyDrive/content/data_visual/AMZN.csv'
data = pd.read_csv(csv_path, index_col=0, parse_dates=True)
price = data['High']

# 축 그리기 및 좌표축 설정
# [[YOUR CODE]]
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

price.plot(ax=ax, style='black')
plt.ylim([1600, 2200])
plt.xlim(['2019-05-01', '2020-03-01'])


# 날짜 정보를 python datetime 자료형으로 변환
min_date = price.idxmin().to_pydatetime()
max_date = price.idxmax().to_pydatetime()

# 주석달기
important_data = [(min_date, "Low Price"), (max_date, "Peak Price")]
# [[YOUR CODE]]
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
                xytext=(d, price.asof(d)+100), # 주석 텍스트가 위치할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정



# 그리드, 타이틀 달기
# [[YOUR CODE]]
plt.grid()
ax.set_title('StockPrice')


# 보여주기
# [[YOUR CODE]]
plt.show()

# %% [markdown]
# # 1-5 간단한 그래프 그리기(3) plot

# %% [markdown]
# - plt.plot() 함수로 그래프를 그리면 matplotlib은 가장 최근의 figure 객체와 그 서브플롯을 그립니다.
# - 만약 서브플롯이 없으면 서브플롯 하나를 생성합니다.
# - plt.plot()의 인자로 x 데이터, y 데이터, 마커 옵션, 색상 등을 지정할 수 있고,

# %%
import numpy as np

# 0에서 10까지 균등한 간격으로 100개의 숫자를 만들라는 뜻입니다.
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x), '--', color='black')
plt.show()

# %% [markdown]
# 서브플롯도 plt.subplot()을 이용해 추가할 수 있어요.

# %%
x = np.linspace(0, 10, 100)
plt.subplot(2,1,1)
plt.plot(x, np.sin(x), 'o', color='orange')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange')
plt.show()

# %% [markdown]
# ## linestyle, marker 옵션

# %% [markdown]
# 라인 스타일은 plot()의 인자로 들어가는데요, 아래와 같이 다양한 방법으로 표기할 수 있습니다.

# %%
x = np.linspace(0, 10, 100)

plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
# Q. y=log(x)의 그래프를 그려봅시다.
# 라인 스타일은 dashdot, 색상은 'm'(magenta)으로 지정해주세요!
x = np.linspace(1, 10, 100)
y = np.log(x)

plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x), '--', color='magenta')


# [[YOUR CODE]]
plt.show()

# %% [markdown]
# 막대그래프의 경우, kind에 bar 옵션을 주어 그릴 수 있습니다.

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)
plt.show()

# %% [markdown]
# 선 그래프도 그리는 방법은 비슷합니다.

# %%
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')
plt.show()

# %% [markdown]
# # 1-6 1간단한 그래프 그리기 (4) 정리해 보자
#
# - 프로그램은 없음

# %% [markdown]
# # 1-7. 그래프 4대 천왕 (1) 데이터 준비

# %% [markdown]
# ## 1) 데이터 불러오기

# %% [markdown]
# - 아래 repo의 데이터는 모두 csv 파일로 되어있어 연습용으로 좋아요.
# https://github.com/mwaskom/seaborn-data
# - default directory: ~ /seaborn-data/ (~(물결표시)는 home directory를 의미합니다

# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# ## 2) 데이터 살펴보기( EDA)

# %% [markdown]
# Pandas의 dataframe을 이용해서 데이터가 어떻게 구성되어 있는지 확인하겠습니다.

# %%
#datafram의 처음 다섯 줄을 보여줍니다.
df = pd.DataFrame(tips)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# dataframe의 shape(row, column의 개수)
df.shape
# Out:
# (244, 7)

# %%
# 데이터의 통계량 정보를 보여줍니다. (평균, 표준편차, 사분위수 등)
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# 각 column의 정보를 보여줍니다. (데이터 크기와 자료형 등)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# 범주형 변수의 카테고리별 개수를 알아볼까요?

# %%
# Q. 다음 코드의 빈칸을 채워주세요.

# 'sex' 변수의 카테고리별 개수
print(df['sex'].value_counts())
print("===========================")

# 'time' 변수의 카테고리별 개수
# [[YOUR CODE]]
print(df['time'].value_counts())
print("===========================")

# 'smoker' 변수의 카테고리별 개수
# [[YOUR CODE]]
print(df['smoker'].value_counts())
print("===========================")

# 'day' 변수의 카테고리별 개수
# [[YOUR CODE]]
print(df['day'].value_counts())
print("===========================")

# 'size' 변수의 카테고리별 개수
# [[YOUR CODE]]
print(df['size'].value_counts())
print("===========================")
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# ...
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64
# ...
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64
# ...
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
# ...
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64
# ...

# %% [markdown]
# #1-8. 그래프 4대 천왕(2) 범주형 데이터

# %% [markdown]
# ## 1) 막대그래프(bar graph)

# %% [markdown]
# ### 1-1) Pandas와 Matplotlib를 활용한 방법
# - 데이터를 x에 series 또는 list, y에 list 형태로 각각 나눠주어야 합니다.

# %%
# df의 첫 5행을 확인해 봅시다.
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - tip 컬럼을 성별에 대한 평균으로 나타내 보겠습니다.

# %%
grouped = df['tip'].groupby(df['sex'])
# Out:
# <ipython-input-34-792b57747127>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df['tip'].groupby(df['sex'])

# %% [markdown]
# - 평균과 데이터 량을 확인 할 수 있습니다.

# %%
grouped.mean()    # 성별에 따른 팀의 평균
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
grouped.size()       # 성별에 따른 데이터 량(팀 횟수)
# Out:
# sex
# Male      157
# Female     87
# Name: tip, dtype: int64

# %% [markdown]
# - 이제 성별에 따른 팁 액수의 평균을 막대그래프로 나타내 보겠습니다.

# %%
import numpy as np
sex = dict(grouped.mean())               # 평균 데이터를 딕셔너리 형태로 바꿔줍니다.
sex
# Out:
# {'Male': np.float64(3.0896178343949043),
#  'Female': np.float64(2.833448275862069)}

# %%
x = list(sex.keys())
x
# Out:
# ['Male', 'Female']

# %%
y = list(sex.values())
y
# Out:
# [np.float64(3.0896178343949043), np.float64(2.833448275862069)]

# %%
import matplotlib.pyplot as plt

plt.bar(x=x, height=y)
plt.ylabel('tip[$]')
plt.title('Tip by Sex')
# Out:
# Text(0.5, 1.0, 'Tip by Sex')

# %% [markdown]
# ## # Q. 요일( day)에 따른 평균 tip의 그래프를 그려보세요

# %%
grouped = df['tip'].groupby(df['day'])
# Out:
# <ipython-input-47-7477a39667f4>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df['tip'].groupby(df['day'])

# %%
grouped.mean()    #요일(day)에 따른 팀의 평
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
grouped.size()    #요일(day)에 따른 데이터
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: tip, dtype: int64

# %%
import numpy as np

day = dict(grouped.mean())
day
# Out:
# {'Thur': np.float64(2.7714516129032254),
#  'Fri': np.float64(2.734736842105263),
#  'Sat': np.float64(2.993103448275862),
#  'Sun': np.float64(3.2551315789473683)}

# %%
x = list(day.keys())
x
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun']

# %%
y=list(day.values())
y
# Out:
# [np.float64(2.7714516129032254),
#  np.float64(2.734736842105263),
#  np.float64(2.993103448275862),
#  np.float64(3.2551315789473683)]

# %%
import matplotlib.pyplot as plt

plt.bar(x=x, height = y)
plt.ylabel('tip[$]')
plt.title('Tip by day')
# Out:
# Text(0.5, 1.0, 'Tip by day')

# %% [markdown]
#  ## Q. 요일( day)에 따른 평균 tip의 그래프를 작성합니다.

# %%
grouped = df['tip'].groupby(df['day'])
grouped.mean()    #요일(day)에 따른 팀의 평균
grouped.size()    #요일(day)에 따른 데이터

import numpy as np
day = dict(grouped.mean())

x = list(day.keys())
y=list(day.values())


import matplotlib.pyplot as plt
plt.bar(x=x, height = y)

plt.ylabel('tip[$]')
plt.title('Tip by Day')
plt.show()
# Out:
# <ipython-input-55-0cf991433153>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df['tip'].groupby(df['day'])

# %% [markdown]
# ## 1-2) Seaborn과 Matplotlib을 활용한 간단한 방법

# %% [markdown]
# - sns.barplot의 인자로 df를 넣고 원하는 컬럼을 지정해 주면 아래와 같이 성별에 대한 tip 평균을 볼 수 있습니다.

# %%
sns.barplot(data = df, x = 'sex', y='tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# - Matplot과 함께 사용하여 figsize, title을 정하는 등 그래프에 다양한 옵션을 넣을 수도 있어요.

# %%
plt.figure(figsize=(10, 6))   # 도화자 사이즈를 정합니다.
sns.barplot(data=df, x='sex', y='tip')

plt.ylim(0, 4)   # y 값의 범위를 정합니다.
plt.title('Tip by sex')    # 그래프 제목을 정합니다.
# Out:
# Text(0.5, 1.0, 'Tip by sex')

# %%
# Seaborn 버젼 확인

import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
plt.figure(figsize=(10, 6))   # 도화자 사이즈를 정합니다.
#sns.barplot(data=df, x='sex', y='tip')
# sns.set_theme(style="whitegrid")  # seaborn 0.12 이상에서 자동 컬러 적용


sns.barplot(data=df, x='sex', y='tip', color='skyblue')  # 단일 색상 고정


plt.ylim(0, 4)   # y 값의 범위를 정합니다.
plt.title('Tip by sex')    # 그래프 제목을 정합니다.
# Out:
# Text(0.5, 1.0, 'Tip by sex')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='sex', y='tip', palette='Set1')     # 빵강, 파랑

plt.ylim(0, 4)
plt.title('Tip by sex')
plt.show()
# Out:
# <ipython-input-65-ba00089038f1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='sex', y='tip', palette='Set1')  # or 'pastel', 'muted', etc.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.barplot(data=df, x='sex', y='tip', palette='Set2')  # or 'pastel', 'muted', etc.

plt.ylim(0, 4)
plt.title('Tip by sex')
plt.show()
# Out:
# <ipython-input-67-076be0a95896>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='sex', y='tip', palette='Set2')  # or 'pastel', 'muted', etc.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.barplot(data=df, x='sex', y='tip', palette='Set3')  # 연한  'pastel', 'muted'

plt.ylim(0, 4)
plt.title('Tip by sex')
plt.show()
# Out:
# <ipython-input-68-b3f20f320863>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='sex', y='tip', palette='Set3')  # or 'pastel', 'muted', etc.

# %% [markdown]
# - 아래는 요일에 따른 tips의 그래프입니다.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='day', y='tip', palette='deep')  #palette = deep를 작성하니 색이 다양. 없으면 같은색

plt.ylim(0, 4)
plt.title('Tip by day')
# Out:
# <ipython-input-70-5b4802a9bbe1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='day', y='tip', palette='deep')
# Text(0.5, 1.0, 'Tip by day')

# %% [markdown]
# - Subplot을 활용할 수도 있고, 범주형 그래프를 나타내기에 좋은 violin plot을 사용할 수도 있습니다.
# - palette 옵션을 주어 더 예쁜 색상을 사용할 수도 있어요.

# %%
fig = plt.figure(figsize=(10,7))

ax1 = fig.add_subplot(2,2,1)
sns.barplot(data=df, x='day', y='tip', palette="ch:.25")

ax2 = fig.add_subplot(2,2,2)
sns.barplot(data=df, x='sex', y='tip')

ax3 = fig.add_subplot(2,2,4)
sns.violinplot(data=df, x='sex', y='tip')

ax4 = fig.add_subplot(2,2,3)
sns.violinplot(data=df, x='day', y='tip', palette="ch:.25")
# Out:
# <ipython-input-84-f195ac3751df>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='day', y='tip', palette="ch:.25")
# <ipython-input-84-f195ac3751df>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='day', y='tip', palette="ch:.25")
# <Axes: xlabel='day', ylabel='tip'>

# %%
from re import S
fig = plt.figure(figsize=(10, 7))

ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df, x = 'day', y='tip',  palette = "ch:.25")

ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df, x = 'sex', y='tip', palette={'Male': 'skyblue', 'Female': 'lightpink'})

ax3 = fig.add_subplot(2, 2, 4)
sns.violinplot(data=df, x = 'sex', y='tip', palette='hls')

ax4 = fig.add_subplot(2, 2, 3)
sns.violinplot(data=df, x = 'day', y='tip',  palette = "ch:.25")
# Out:
# <ipython-input-83-889588033447>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x = 'day', y='tip',  palette = "ch:.25")
# <ipython-input-83-889588033447>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x = 'sex', y='tip', palette={'Male': 'skyblue', 'Female': 'lightpink'})
# <ipython-input-83-889588033447>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x = 'sex', y='tip', palette='hls')
# <ipython-input-83-889588033447>:14: FutureWarning:
#
# ...

# %% [markdown]
# catplot을 사용하여 나타낼 수도 있습니다.

# %%
sns.catplot(x='day', y='tip', jitter=False, data=tips)

# %% [markdown]
# ### Q. 시간대(time)에 따른 tips의 그래프를 catplot으로 표현해보세요!

# %%
sns.catplot(x='time', y='tip', jitter=False, data=tips)

# %% [markdown]
# # 1-9 그래프 4대 천왕(3) 수치형 데이터

# %% [markdown]
# ## 2) 산점도(scatter plot)

# %% [markdown]
# ### hue인자에 'day'를 주어 요일(day)에 따른 tip과 total_bill의 관계를 시각화해 봅시다.

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', palette='ch:r=-.2, d=.3_r')
# Out:
# <ipython-input-98-57922cf392a4>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='total_bill', y='tip', palette='ch:r=-.2, d=.3_r')
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 3) 선 그래프(line graph)

# %% [markdown]
# tips 예제로는 선 그래프 설명이 어려워서, numpy를 이용하여 데이터를 생성 후 그래프를 그려보겠습니다.

# %%
# np.random.randh 함수 : 표준 정규분포에서 난수를 생성하는 함수
# cumsum() : 누적함을 구하는 함수

plt.plot(np.random.randn(50).cumsum())
plt.show()

# %% [markdown]
# 앞 스텝에서 plt.plot() 함수의 예제로 설명했던 그래프도 선 그래프입니다.

# %%
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x), 'o')   # o는 알파 o
plt.plot(x, np.cos(x))

plt.show()

# %%
x = np.linspace(0, 20, 200)

plt.plot(x, np.sin(x), 'o')   # o는 알파 o
plt.plot(x, np.cos(x))

plt.show()

# %%
x = np.linspace(0, 10, 200)

plt.plot(x, np.sin(x), 'v')   # o는 알파 o
plt.plot(x, np.cos(x))

plt.show()

# %%
x = np.linspace(0, 10, 50)

plt.plot(x, np.sin(x), 'o')   # o는 알파 o
plt.plot(x, np.cos(x), 'x')

plt.show()

# %% [markdown]
# Seaborn을 활용하면 다음과 같이 그릴 수 있습니다.

# %%
sns.lineplot(x=x, y=np.sin(x))
sns.lineplot(x=x, y=np.cos(x))
# Out:
# <Axes: >

# %% [markdown]
# ## 4) 히스토그램

# %% [markdown]
# 다음과 같은 데이터의 히스토그램을 만들어보겠습니다.
#
# - x1은 평균은 100이고 표준편차는 15인 정규분포를 따릅니다.
# - x2는 평균은 130이고 표준편차는 15인 정규분포를 따릅니다.
# - 도수를 50개의 구간으로 표시하며, 확률 밀도가 아닌 빈도로 표기합니다.

# %%
#그래프 데이터
mu1, mu2, sigma = 100, 130, 15
x1 = mu1 + sigma*np.random.randn(10000)
x2 = mu2 + sigma*np.random.randn(10000)

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
patches = ax1.hist(x1, bins=50, density=False)  # bins는 x값을 총 50개 구간으로 나눈다는 뜻입니다.
patches = ax1.hist(x2, bins=50, density=False, alpha=0.5)
ax1.xaxis.set_ticks_position('bottom')  # x축의 눈금을 아래 표시
ax1.yaxis.set_ticks_position('left')  # y축의 눈금을 왼쪽에 표시

# 라벨, 타이틀 달기
plt.xlabel('Bins')
plt.ylabel('Number of Values in Bin')
ax1.set_title('Two Frequency Distributions')

# 보여주기
plt.show()

# %% [markdown]
# ## 예제 데이터의 히스토그램

# %% [markdown]
# tips 데이터의 total_bill과 tips에 대해 히스토그램을 만들어 보겠습니다.

# %%
sns.histplot(df['total_bill'], label="total_bill")

# legend()를 이용하여 label을 표시해줍니다.
sns.histplot(df['tip'], label="tip").legend()

# %% [markdown]
# 전체 결제 금액 대비 팁의 비율을 나타내는 히스토그램을 그려보겠습니다.

# %% [markdown]
# ## Q. pyplot을 이용해서 그려봅시다.

# %%
# Q. pyplot을 이용해서 그려봅시다.
# pyplot: matplotlib 패키지 안에 포함된 서브모듈로, 그래프를 그리는 함수 인터페이스를 제공하는 도구

# bin의 개수는 50개로 지정해주세요.

#df['tip_pct'] =  # [[YOUR CODE]]
# [[YOUR CODE]]


#=============
import matplotlib.pyplot as plt

# tip_pct = tip / total_bill 계산
df['tip_pct'] = df['tip'] / df['total_bill']

# 히스토그램 그리기 (pyplot 기반)
plt.figure(figsize=(10, 6))
plt.hist(df['tip_pct'], bins=50)  # bin 수를 50개로 지정

plt.xlabel('Tip Percentage')
plt.ylabel('Number of Values in Bin')
plt.title('Histogram of Tip Percentage')
plt.show()

# %% [markdown]
# ## Q. 이번에는 seaborn을 이용해서 그려봅시다.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# tip_pct = tip / total_bill 계산
df['tip_pct'] = df['tip'] / df['total_bill']

# Seaborn을 활용한 히스토그램
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='tip_pct', bins=50)  # bin 수를 50개로 지정

plt.xlabel('Tip Percentage')
plt.ylabel('Number of Values in Bin')
plt.title('Histogram of Tip Percentage')
plt.show()

# %%
df['tip_pct'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # 1-10 시계열 데이터 시각화하기

# %% [markdown]
# ## 1) 데이터 가져오기

# %%
pwd
# Out:
# '/content'

# %%
#Google Drive 마운트

from google.colab import drive
drive.mount('/content/data_visual')

#코드 실행 후 Google 계정 인증 절차를 따라야 합니다
# Out:
# Mounted at /content/data_visual

# %%
import pandas as pd

sns.set(style='whitegrid')
# %matplotlib inline


# 데이터 불러오기
#csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/flights.csv"
#data = pd.read_csv(csv_path)
#csv_path = os.getenv("HOME") + '/content/data_visual/MyDrive/content/data_visual/titanic.csv'

data = pd.read_csv('/content/data_visual/MyDrive/content/data_visual/flights.csv')

flights = pd.DataFrame(data)
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ## 2) 그래프 그리기

# %%
# seaborn barplot
sns.barplot(data=flights, x='year', y='passengers', palette='Set2')  #palette='Set2'를 입력해야 다양한
# Out:
# <ipython-input-125-d14e87bd97b0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=flights, x='year', y='passengers',palette='Set2')
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ##  Q. seaborn pointplot을 그려봅시다.

# %%
sns.pointplot(data=flights, x='year', y='passengers', palette='Set2')
# Out:
# <ipython-input-128-12d5d9e8e886>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.pointplot(data=flights, x='year', y='passengers', palette='Set2')
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## Q. seaborn lineplot을 그려봅시다.

# %%
sns.lineplot(data=flights, x='year', y='passengers', palette='Set2')
# Out:
# <ipython-input-129-69ffde9d1e03>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=flights, x='year', y='passengers', palette='Set2')
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# 달별로 나누어 보기 위해 hue 인자에 'month'를 할당합니다.

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', palette='ch:.50')
plt.legend(bbox_to_anchor=(1.03, 1), loc=2)           #legend 그래프 밖에 추가하기

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', palette='Set2')
plt.legend(bbox_to_anchor=(1.03, 1), loc=2)

# %% [markdown]
# # 히스토그램

# %%
sns.histplot(flights['passengers'])
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.histplot(data=flights, x='passengers', hue='year', palette='Set1')
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.histplot(data=flights, x='passengers', hue='year', palette='Set2')
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.histplot(data=flights, x='passengers', hue='year', palette='hls')
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %% [markdown]
# # 1-11 Heatmap

# %% [markdown]
# - pandas의 dataframe의 pivot() 메서드를 사용합니다.
# - flights(DataFrame)을 탑승객 수를 year과 month로 pivot 해보겠습니다.

# %%
pivot = flights.pivot(index='year', columns = 'month', values = 'passengers')
pivot
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
# 1954     227     293       229       188      204   302   264    235  234
# 1955     269     347       278       233      242   364   315    267  270
# 1956     313     405       306       277      284   413   374    317  318
# 1957     348     467       336       301      315   465   422    356  355
# 1958     348     505       337       318      340   491   435    362  363
# 1959     396     559       405       342      360   548   472    406  420
# 1960     461     606       432       391      417   622   535    419  472
#
# ...

# %%
sns.heatmap(pivot)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(pivot, linewidths=.2, annot=True, fmt='d')

# linewidth=.2 : 셀 간 경계선을 0.2 pt 두께로 그림
# annot=True : 각 셀에 실제 수자(값)를 표시
# fmt ='d'  : 셀 숫자를 정수 형식으로 표시 (%d 포맷)

# 히트맵 내부의 숫자 : 각 셀(연도 x 월)의 할공기 승객
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# ##  Q. cmap 인자를 "YlGnBu"로 지정하여 heatmap을 그려보세요!
#
# - cmap='YlGnBu'는 Yellow-Green-Blue 계열의 색상 팔레트
# - 값이 작을수록 밝은 노랑, 클수록 진한 파랑

# %%
sns.heatmap(pivot, linewidths=0.2, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# # 종합퀴즈

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset("tips")

# %% [markdown]
# ## Q. 시간대(time)에 따른 tip과 total_bill의 관계를 scatter plot으로 시각화해봅시다.

# %%
# scatter plot 산점도 시각화

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='total_bill', y='tip', hue='time', )

plt.title('Tip vs Total Bill by Time of Day')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ## Q. seaborn jointplot의 문서를 참고하여 아래와 같은 그래프를 그려보세요!

# %%
import seaborn as sns

sns.jointplot(data=df, x='total_bill', y='tip', hue='time', kind='scatter')

# hue ='time'  : 범주형 변수인 시간대(Lunch, Dinner)에 따라 색상 구분
# Lunch(파랑),, Dinner(주황으로 분

# kind='scatter' : 중심 부분을 산점도로 시화

# 주변그래프:
# 산당 : total_bill의 밀도 분포
# 오른쪽 : tip의밀도 분포
# 두 시간대 간 결재 금액과 팁의 분포 차이까지 시각적으로 파악 가능
