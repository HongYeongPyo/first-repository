# %% [markdown]
# <a href="https://colab.research.google.com/github/HongYeongPyo/first-repository/blob/master/5%EB%A8%B8%EC%8B%A0_2%EC%82%AC%EC%9D%B4%ED%82%B7%EB%9F%B0_6%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2-6 머신러닝

# %% [markdown]
# ## 1) 검증데이터 관리

# %%
#  당뇨병 데이터 불러오기
from sklearn.datasets  import  load_diabetes
cancer_df_df = load_diabetes()

# %%
# 데이터프레임으로 만들기
cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
# 타켓 추가하기
cancer_df['target'] = dataset.target
cancer_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# 검증데이터 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
   cancer_df.drop('target', axis=1), cancer_df['target'], test_size=0.3, random_state=1004)

# %%
# train 데이터 확인(X)
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 232  0.012648  0.050680  0.000261 -0.011420  0.039710  0.057245 -0.039719
# 81   0.012648  0.050680 -0.022373 -0.029770  0.010815  0.028435 -0.021311
# 227  0.067136  0.050680 -0.029918  0.057437 -0.000193 -0.015719  0.074412
# 334 -0.060003  0.050680 -0.047163 -0.022885 -0.071743 -0.057681 -0.006584
# 83  -0.038207 -0.044642  0.009961 -0.046985 -0.059359 -0.052983 -0.010266
#
#            s4        s5        s6
# 232  0.056081  0.024055  0.032059
# 81   0.034309 -0.006081 -0.001078
# 227 -0.050564 -0.038460  0.007207
# 334 -0.039493 -0.062917 -0.054925
# 83  -0.039493 -0.015999 -0.042499

# %%
# 학습 데이터 확인(y)
y_train.head()
# Out:
# 232    259.0
# 81      51.0
# 227    108.0
# 334     72.0
# 83     210.0
# Name: target, dtype: float64

# %%
# 데이터 크기
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((309, 10), (133, 10), (309,), (133,))

# %% [markdown]
# ## 2) 의사결정나무(DecisionTree)

# %%
# 머신러닝(분류)
from sklearn.tree import DecisionTreeClassifier

# %%
# 모델 선택
model = DecisionTreeClassifier()

# %%
# 학습
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 예측
pred = model.predict(X_test)
pred
# Out:
# array([109.,  83., 217.,  95., 171., 178., 127.,  61., 111., 139.,  78.,
#        202., 198., 137.,  91., 139., 252., 115., 141.,  99., 151.,  53.,
#        232., 202., 262., 198.,  63., 109., 173., 198., 248., 151., 107.,
#        116.,  74., 115.,  61., 191., 210., 303., 109., 152., 249., 200.,
#        261.,  91., 202., 151., 136., 154., 192., 283., 200.,  61., 202.,
#         63., 242., 185.,  52.,  98., 270.,  78., 280.,  55., 281.,  88.,
#        131., 173., 180., 303., 191., 232.,  61., 115.,  93., 178., 252.,
#        257., 142., 118., 151., 202.,  57., 183.,  57., 308., 192., 144.,
#         83., 131., 200., 275.,  65.,  72.,  60., 135., 252.,  94.,  61.,
#        220.,  53., 200., 109., 161., 123., 216., 317.,  77., 158., 160.,
#         39., 141.,  91.,  39., 198., 173., 150., 270., 225., 270.,  81.,
#        118.,  61.,  85., 225., 177.,  53.,  53., 225., 113.,  64., 187.,
#        281.])

# %% [markdown]
# ## 3) 평가 (accuracy)

# %%
# 정확도 accuacy_score(실제값, 예측값)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.007518796992481203

# %% [markdown]
# ## 2. 머신러닝 : 회귀

# %% [markdown]
# ### 1) 검증데이터 관리

# %%
#  당뇨병 데이터 불러오기
from sklearn.datasets  import  load_diabetes

dataset = load_diabetes()
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
# 데이터프레임으로 만들기
diabetes_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
# 타켓 추가하기
diabetes_df['target'] = dataset.target
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# 검증데이터 관리

from sklearn.model_selection import  train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    diabetes_df.drop('target', axis=1), diabetes_df['target'], test_size=0.3, random_state=1004
)

# %%
# train 데이터 확인(X)
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 232  0.012648  0.050680  0.000261 -0.011420  0.039710  0.057245 -0.039719
# 81   0.012648  0.050680 -0.022373 -0.029770  0.010815  0.028435 -0.021311
# 227  0.067136  0.050680 -0.029918  0.057437 -0.000193 -0.015719  0.074412
# 334 -0.060003  0.050680 -0.047163 -0.022885 -0.071743 -0.057681 -0.006584
# 83  -0.038207 -0.044642  0.009961 -0.046985 -0.059359 -0.052983 -0.010266
#
#            s4        s5        s6
# 232  0.056081  0.024055  0.032059
# 81   0.034309 -0.006081 -0.001078
# 227 -0.050564 -0.038460  0.007207
# 334 -0.039493 -0.062917 -0.054925
# 83  -0.039493 -0.015999 -0.042499

# %%
# 학습 데이터 학인(y)
y_train.head()
# Out:
# 232    259.0
# 81      51.0
# 227    108.0
# 334     72.0
# 83     210.0
# Name: target, dtype: float64

# %%
# 데이터 크기
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((309, 10), (133, 10), (309,), (133,))

# %% [markdown]
# ## 2) 선형회귀(LinearRegression)

# %%
# 머신러닝(회귀)
from sklearn.linear_model import  LinearRegression

# %%
# 모델 선택
model = LinearRegression()

# %%
# 학습
model.fit(X_train, y_train)

# 예측
pred = model.predict(X_test)
pred
# Out:
# array([128.42468606, 135.08774266, 154.78504343, 106.09306564,
#        149.54478558, 165.32708009, 140.29166154, 167.9600165 ,
#         69.44851384, 189.42811434, 144.98692247, 150.10700196,
#        211.15983244, 108.59257071, 160.3856331 , 154.09855476,
#        198.78116874, 101.16062264, 165.82852734, 196.03659567,
#        147.16472505, 108.25668788, 207.27889551, 127.53191954,
#        181.85997027, 228.49975565,  86.59589481, 155.35081963,
#        182.49593133, 182.96390209, 207.63119699, 199.81134435,
#        157.35809543,  61.82465786,  88.11634158,  95.75033061,
#        134.03120864,  85.95903914, 177.69650387, 249.40014721,
#        171.77206628, 204.71572412, 239.12149428,  89.24927278,
#        244.20385113, 180.36498587, 161.10608699, 119.14846149,
#        102.81815844, 153.35400825, 129.06743815, 208.80206598,
#        107.93927973, 138.81355171, 166.04217088,  86.04455248,
#        181.03094575, 117.97907348,  79.04947426, 127.20387612,
# ...

# %% [markdown]
# ### 3) 평가

# %%
# 정확도 mean_squared_error(실제값,예측값 )
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, pred)
# Out:
# 3229.454787929743
